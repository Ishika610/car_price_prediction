# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd
df = pd.read_csv('car data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %%
df.shape
# Out:
# (205, 26)

# %%
df.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
df.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
#      boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 200       3.78    3.15              9.5        114     5400      23
# 201       3.78    3.15              8.7        160     5300      19
# 202       3.58    2.87              8.8        134     5500      18
# 203       3.01    3.40             23.0        106     4800      26
# 204       3.78    3.15              9.5        114     5400      19
#
#      highwaympg    price
# 200          28  16845.0
# 201          25  19045.0
# 202          23  21485.0
# 203          27  22470.0
# 204          25  22625.0
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.CarName.unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
#        'mazda glc deluxe', 'mazda 626', 'mazda glc', 'mazda rx-7 gs',
#        'mazda glc 4', 'mazda glc custom l', 'mazda glc custom',
#        'buick electra 225 custom', 'buick century luxus (sw)',
#        'buick century', 'buick skyhawk', 'buick opel isuzu deluxe',
#        'buick skylark', 'buick century special',
#        'buick regal sport coupe (turbo)', 'mercury cougar',
#        'mitsubishi mirage', 'mitsubishi lancer', 'mitsubishi outlander',
#        'mitsubishi g4', 'mitsubishi mirage g4', 'mitsubishi montero',
#        'mitsubishi pajero', 'Nissan versa', 'nissan gt-r', 'nissan rogue',
#        'nissan latio', 'nissan titan', 'nissan leaf', 'nissan juke',
#        'nissan note', 'nissan clipper', 'nissan nv200', 'nissan dayz',
#        'nissan fuga', 'nissan otti', 'nissan teana', 'nissan kicks',
#        'peugeot 504', 'peugeot 304', 'peugeot 504 (sw)', 'peugeot 604sl',
#        'peugeot 505s turbo diesel', 'plymouth fury iii',
#        'plymouth cricket', 'plymouth satellite custom (sw)',
#        'plymouth fury gran sedan', 'plymouth valiant', 'plymouth duster',
#        'porsche macan', 'porcshce panamera', 'porsche cayenne',
#        'porsche boxter', 'renault 12tl', 'renault 5 gtl', 'saab 99e',
#        'saab 99le', 'saab 99gle', 'subaru', 'subaru dl', 'subaru brz',
#        'subaru baja', 'subaru r1', 'subaru r2', 'subaru trezia',
#        'subaru tribeca', 'toyota corona mark ii', 'toyota corona',
#        'toyota corolla 1200', 'toyota corona hardtop',
#        'toyota corolla 1600 (sw)', 'toyota carina', 'toyota mark ii',
#        'toyota corolla', 'toyota corolla liftback',
#        'toyota celica gt liftback', 'toyota corolla tercel',
#        'toyota corona liftback', 'toyota starlet', 'toyota tercel',
#        'toyota cressida', 'toyota celica gt', 'toyouta tercel',
#        'vokswagen rabbit', 'volkswagen 1131 deluxe sedan',
#        'volkswagen model 111', 'volkswagen type 3', 'volkswagen 411 (sw)',
#        'volkswagen super beetle', 'volkswagen dasher', 'vw dasher',
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'], dtype=object)

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
Company = df['CarName'].apply(lambda x: x.split(' ')[0])
df['CarName']=Company
df['CarName']
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 200          volvo
# 201          volvo
# 202          volvo
# 203          volvo
# 204          volvo
# Name: CarName, Length: 205, dtype: object

# %%
df.head()
# Out:
#    car_ID  symboling      CarName fueltype aspiration doornumber      carbody  \
# 0       1          3  alfa-romero      gas        std        two  convertible
# 1       2          3  alfa-romero      gas        std        two  convertible
# 2       3          1  alfa-romero      gas        std        two    hatchback
# 3       4          2         audi      gas        std       four        sedan
# 4       5          2         audi      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0        rwd          front       88.6  ...         130        mpfi
# 1        rwd          front       88.6  ...         130        mpfi
# 2        rwd          front       94.5  ...         152        mpfi
# 3        fwd          front       99.8  ...         109        mpfi
# 4        4wd          front       99.4  ...         136        mpfi
#
#    boreratio  stroke compressionratio horsepower  peakrpm citympg  highwaympg  \
# 0       3.47    2.68              9.0        111     5000      21          27
# 1       3.47    2.68              9.0        111     5000      21          27
# 2       2.68    3.47              9.0        154     5000      19          26
# 3       3.19    3.40             10.0        102     5500      24          30
# 4       3.19    3.40              8.0        115     5500      18          22
#
#      price
# 0  13495.0
# 1  16500.0
# 2  16500.0
# 3  13950.0
# 4  17450.0
#
# [5 rows x 26 columns]

# %%
df.drop('car_ID',axis=1,inplace=True)

# %%
df.CarName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %%
df['CarName']=df['CarName'].str.replace('maxda','mazda')
df['CarName']=df['CarName'].str.replace('Nissan','nissan')
df['CarName']=df['CarName'].str.replace('porcshce','porsche')
df['CarName']=df['CarName'].str.replace('toyouta','toyota')
df['CarName']=df['CarName'].str.replace('vokswagen','volkswagen')
df['CarName']=df['CarName'].str.replace('vw','volkswagen')
df.CarName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
df.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
plt.hist(df.price)
# Out:
# (array([83., 45., 35., 18.,  6.,  3.,  5.,  7.,  2.,  1.]),
#  array([ 5118. ,  9146.2, 13174.4, 17202.6, 21230.8, 25259. , 29287.2,
#         33315.4, 37343.6, 41371.8, 45400. ]),
#  <BarContainer object of 10 artists>)

# %%
df_numerical = df.select_dtypes(exclude='object')
df_numerical_cols = df_numerical.columns.tolist()
df_numerical_cols
# Out:
# ['symboling',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
df_categorical = df.select_dtypes(include='object')
df_categorical_cols = df_categorical.columns.tolist()
df_categorical_cols
# Out:
# ['CarName',
#  'fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem']

# %%
plt1 = df.CarName.value_counts().plot(kind='bar')
plt.title('Companies Data')
plt1.set(xlabel = 'Company name', ylabel='Frequency')
plt1.plot()
# Out:
# []

# %%
plt.figure(figsize=(20,4))

plt.subplot(1,2,1)
plt1 = df['fueltype'].value_counts().plot(kind='bar')
plt1.set(xlabel = 'fuel type', ylabel='Frequency')
plt1.plot()

plt.subplot(1,2,2)
plt1 = df['doornumber'].value_counts().plot(kind='bar')
plt1.set(xlabel = 'door number', ylabel='Frequency')
plt1.plot()
# Out:
# []

# %%
plt.figure(figsize=(20,4))

plt.subplot(1,2,1)
plt1 = df.drivewheel.value_counts().plot(kind='bar')
plt1.set(xlabel = 'drivewheel', ylabel='Frequency')
plt1.plot()

plt.subplot(1,2,2)
plt1 = df.carbody.value_counts().plot(kind='bar')
plt1.set(xlabel = 'carbody', ylabel='Frequency')
plt1.plot()
# Out:
# []

# %%
plt.figure(figsize=(20,4))

plt.subplot(1,2,1)
plt1 = df.aspiration.value_counts().plot(kind='bar')
plt1.set(xlabel = 'aspiration', ylabel='Frequency')
plt1.plot()

plt.subplot(1,2,2)
plt1 = df.fuelsystem.value_counts().plot(kind='bar')
plt1.set(xlabel = 'fuelsystem', ylabel='Frequency')
plt1.plot()
# Out:
# []

# %%
plt.figure(figsize=(20,4))

plt.subplot(1,2,1)
plt1 = df.cylindernumber.value_counts().plot(kind='bar')
plt1.set(xlabel = 'cylindernumber', ylabel='Frequency')
plt1.plot()

plt.subplot(1,2,2)
plt1 = df.enginetype.value_counts().plot(kind='bar')
plt1.set(xlabel = 'enginetype', ylabel='Frequency')
plt1.plot()
# Out:
# []

# %% [markdown]
# *   toyota is the most preferred car and mercury is the least preferred car
# *   car with fueltype as gas are more preferred as compared to that of diesel
#
#
# *   fwd drivewheel and sedan carbody are sold more
# *   cars with four doors are preferred more than the cars with two doors
#
#
# *   ohc engine is most prefered & dohcv is least prefered

# %%
import seaborn as sns
plt.figure(figsize=(20,4))
ax = plt.subplot(1, 2, 1)
sns.boxplot(y = df.wheelbase, data = df, ax = ax)

ax = plt.subplot(1, 2, 2)
sns.boxplot(y = df.carwidth, data = df, ax = ax)
# Out:
# <Axes: ylabel='carwidth'>

# %%
plt.figure(figsize=(20,4))
ax = plt.subplot(1, 2, 1)
sns.boxplot(y = df.carlength, data = df, ax = ax)

ax = plt.subplot(1, 2, 2)
sns.boxplot(y = df.highwaympg, data = df, ax = ax)
# Out:
# <Axes: ylabel='highwaympg'>

# %%
plt.figure(figsize=(20,4))
ax = plt.subplot(1, 3, 1)
sns.boxplot(y = df.compressionratio, data = df, ax = ax)

ax = plt.subplot(1, 3, 2)
sns.boxplot(y = df.stroke, data = df, ax = ax)
ax = plt.subplot(1, 3, 3)
sns.boxplot(y = df.boreratio, data = df, ax = ax)
# Out:
# <Axes: ylabel='boreratio'>

# %%
plt.figure(figsize=(20,4))
ax = plt.subplot(1, 3, 1)
sns.boxplot(y = df.curbweight, data = df, ax = ax)
ax = plt.subplot(1, 3, 2)
sns.boxplot(y = df.enginesize, data = df, ax = ax)
ax = plt.subplot(1, 3, 3)
sns.boxplot(y = df.carheight, data = df, ax = ax)
# Out:
# <Axes: ylabel='carheight'>

# %%
plt.figure(figsize=(20,4))
ax = plt.subplot(1, 3, 1)
sns.boxplot(y = df.citympg, data = df, ax = ax)

ax = plt.subplot(1, 3, 2)
sns.boxplot(y = df.peakrpm, data = df, ax = ax)
ax = plt.subplot(1, 3, 3)
sns.boxplot(y = df.horsepower, data = df, ax = ax)
# Out:
# <Axes: ylabel='horsepower'>

# %%
import seaborn as sns
plt.figure(figsize=(20,4))
ax = plt.subplot(1, 3, 1)
sns.boxplot(x = df.fueltype ,y = df['price'], data = df, ax = ax)
ax = plt.subplot(1, 3, 2)
sns.boxplot(x = df.aspiration ,y = df['price'], data = df, ax = ax)
ax = plt.subplot(1, 3, 3)
sns.boxplot(x = df.carbody ,y = df['price'], data = df, ax = ax)
# Out:
# <Axes: xlabel='carbody', ylabel='price'>

# %%
import seaborn as sns
plt.figure(figsize=(20,4))
ax = plt.subplot(1, 3, 1)
sns.boxplot(x = df.enginetype ,y = df['price'], data = df, ax = ax)
ax = plt.subplot(1, 3, 2)
sns.boxplot(x = df.fuelsystem ,y = df['price'], data = df, ax = ax)
ax = plt.subplot(1, 3, 3)
sns.boxplot(x = df.cylindernumber ,y = df['price'], data = df, ax = ax)
# Out:
# <Axes: xlabel='cylindernumber', ylabel='price'>

# %%
import seaborn as sns
plt.figure(figsize=(20,4))
ax = plt.subplot(1, 3, 1)
sns.boxplot(x = df.enginelocation ,y = df['price'], data = df, ax = ax)
ax = plt.subplot(1, 3, 2)
sns.boxplot(x = df.drivewheel ,y = df['price'], data = df, ax = ax)
# Out:
# <Axes: xlabel='drivewheel', ylabel='price'>

# %% [markdown]
# *   engine located at front are prefered as they are cheaper while cars with rear engines are expensive.
# *   rwd drivewheel is mostly prefered although its slightly costly.
#
# *   Most of the cars have 4 cylinders and we increase the number of cylinders the price also increases
# *   Convertible and hathback carbody cars are costlier compared to hatchback and wagon
#
# *   ohcv is the costliest engine and therefore purchased less while ohc is prefered more
# *   cars with gas are prefered as they are comparatively cheaper than diesel cars.

# %%
import seaborn as sns
plt.figure(figsize=(20,4))
ax = plt.subplot(1, 3, 1)
sns.scatterplot(x = df.carwidth ,y = df['price'], data = df, ax = ax)
ax = plt.subplot(1, 3, 2)
sns.scatterplot(x = df.carlength ,y = df['price'], data = df, ax = ax)
ax = plt.subplot(1, 3, 3)
sns.scatterplot(x = df.carheight ,y = df['price'], data = df, ax = ax)
# Out:
# <Axes: xlabel='carheight', ylabel='price'>

# %%
import seaborn as sns
plt.figure(figsize=(20,4))
ax = plt.subplot(1, 3, 1)
sns.scatterplot(x = df.peakrpm ,y = df['price'], data = df, ax = ax)
ax = plt.subplot(1, 3, 2)
sns.scatterplot(x = df.highwaympg ,y = df['price'], data = df, ax = ax)
ax = plt.subplot(1, 3, 3)
sns.scatterplot(x = df.citympg ,y = df['price'], data = df, ax = ax)
# Out:
# <Axes: xlabel='citympg', ylabel='price'>

# %%
import seaborn as sns
plt.figure(figsize=(20,4))
ax = plt.subplot(1, 3, 1)
sns.scatterplot(x = df.enginesize ,y = df['price'], data = df, ax = ax)
ax = plt.subplot(1, 3, 2)
sns.scatterplot(x = df.boreratio ,y = df['price'], data = df, ax = ax)
ax = plt.subplot(1, 3, 3)
sns.scatterplot(x = df.stroke ,y = df['price'], data = df, ax = ax)
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %%
import seaborn as sns
plt.figure(figsize=(20,4))
ax = plt.subplot(1, 2, 1)
sns.scatterplot(x = df.curbweight ,y = df['price'], data = df, ax = ax)
ax = plt.subplot(1, 2, 2)
sns.scatterplot(x = df.compressionratio ,y = df['price'], data = df, ax = ax)
# Out:
# <Axes: xlabel='compressionratio', ylabel='price'>

# %% [markdown]
# *   As we increase carwidth, carlength and carheight, the price also increases
#
# *   Car with high curbweight has high price
# *   high engine sized cars are costlier than others.
#
#
# *   Cars with high boreratio are expensive.

# %%
print(df_numerical_cols)
# Out:
# ['symboling', 'wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke', 'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price']

# %%
df.corr()
# Out:
# <ipython-input-165-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   symboling  wheelbase  carlength  carwidth  carheight  \
# symboling          1.000000  -0.531954  -0.357612 -0.232919  -0.541038
# wheelbase         -0.531954   1.000000   0.874587  0.795144   0.589435
# carlength         -0.357612   0.874587   1.000000  0.841118   0.491029
# carwidth          -0.232919   0.795144   0.841118  1.000000   0.279210
# carheight         -0.541038   0.589435   0.491029  0.279210   1.000000
# curbweight        -0.227691   0.776386   0.877728  0.867032   0.295572
# enginesize        -0.105790   0.569329   0.683360  0.735433   0.067149
# boreratio         -0.130051   0.488750   0.606454  0.559150   0.171071
# stroke            -0.008735   0.160959   0.129533  0.182942  -0.055307
# compressionratio  -0.178515   0.249786   0.158414  0.181129   0.261214
# horsepower         0.070873   0.353294   0.552623  0.640732  -0.108802
# peakrpm            0.273606  -0.360469  -0.287242 -0.220012  -0.320411
# citympg           -0.035823  -0.470414  -0.670909 -0.642704  -0.048640
# highwaympg         0.034606  -0.544082  -0.704662 -0.677218  -0.107358
# price             -0.079978   0.577816   0.682920  0.759325   0.119336
#
#                   curbweight  enginesize  boreratio    stroke  \
# symboling          -0.227691   -0.105790  -0.130051 -0.008735
# wheelbase           0.776386    0.569329   0.488750  0.160959
# carlength           0.877728    0.683360   0.606454  0.129533
# carwidth            0.867032    0.735433   0.559150  0.182942
# carheight           0.295572    0.067149   0.171071 -0.055307
# curbweight          1.000000    0.850594   0.648480  0.168790
# enginesize          0.850594    1.000000   0.583774  0.203129
# boreratio           0.648480    0.583774   1.000000 -0.055909
# stroke              0.168790    0.203129  -0.055909  1.000000
# compressionratio    0.151362    0.028971   0.005197  0.186110
# horsepower          0.750739    0.809769   0.573677  0.080940
# peakrpm            -0.266243   -0.244660  -0.254976 -0.067964
# citympg            -0.757414   -0.653658  -0.584532 -0.042145
# highwaympg         -0.797465   -0.677470  -0.587012 -0.043931
# price               0.835305    0.874145   0.553173  0.079443
#
#                   compressionratio  horsepower   peakrpm   citympg  \
# symboling                -0.178515    0.070873  0.273606 -0.035823
# wheelbase                 0.249786    0.353294 -0.360469 -0.470414
# carlength                 0.158414    0.552623 -0.287242 -0.670909
# carwidth                  0.181129    0.640732 -0.220012 -0.642704
# carheight                 0.261214   -0.108802 -0.320411 -0.048640
# curbweight                0.151362    0.750739 -0.266243 -0.757414
# enginesize                0.028971    0.809769 -0.244660 -0.653658
# boreratio                 0.005197    0.573677 -0.254976 -0.584532
# stroke                    0.186110    0.080940 -0.067964 -0.042145
# compressionratio          1.000000   -0.204326 -0.435741  0.324701
# horsepower               -0.204326    1.000000  0.131073 -0.801456
# peakrpm                  -0.435741    0.131073  1.000000 -0.113544
# citympg                   0.324701   -0.801456 -0.113544  1.000000
# highwaympg                0.265201   -0.770544 -0.054275  0.971337
# price                     0.067984    0.808139 -0.085267 -0.685751
#
#                   highwaympg     price
# symboling           0.034606 -0.079978
# wheelbase          -0.544082  0.577816
# carlength          -0.704662  0.682920
# carwidth           -0.677218  0.759325
# carheight          -0.107358  0.119336
# curbweight         -0.797465  0.835305
# enginesize         -0.677470  0.874145
# boreratio          -0.587012  0.553173
# stroke             -0.043931  0.079443
# compressionratio    0.265201  0.067984
# horsepower         -0.770544  0.808139
# peakrpm            -0.054275 -0.085267
# citympg             0.971337 -0.685751
# highwaympg          1.000000 -0.697599
# price              -0.697599  1.000000

# %%
plt.figure(figsize = (20, 10))
sns.heatmap(df.corr(), annot = True, cmap="PiYG")
plt.show()
# Out:
# <ipython-input-166-c5e445086634>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True, cmap="PiYG")

# %%
corr_matrix = df.corr().abs()
import numpy as np
upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape),k=1).astype(bool))
print(upper_tri)
# Out:
#                   symboling  wheelbase  carlength  carwidth  carheight  \
# symboling               NaN   0.531954   0.357612  0.232919   0.541038
# wheelbase               NaN        NaN   0.874587  0.795144   0.589435
# carlength               NaN        NaN        NaN  0.841118   0.491029
# carwidth                NaN        NaN        NaN       NaN   0.279210
# carheight               NaN        NaN        NaN       NaN        NaN
# curbweight              NaN        NaN        NaN       NaN        NaN
# enginesize              NaN        NaN        NaN       NaN        NaN
# boreratio               NaN        NaN        NaN       NaN        NaN
# stroke                  NaN        NaN        NaN       NaN        NaN
# compressionratio        NaN        NaN        NaN       NaN        NaN
# horsepower              NaN        NaN        NaN       NaN        NaN
# peakrpm                 NaN        NaN        NaN       NaN        NaN
# citympg                 NaN        NaN        NaN       NaN        NaN
# highwaympg              NaN        NaN        NaN       NaN        NaN
# price                   NaN        NaN        NaN       NaN        NaN
#
#                   curbweight  enginesize  boreratio    stroke  \
# symboling           0.227691    0.105790   0.130051  0.008735
# wheelbase           0.776386    0.569329   0.488750  0.160959
# carlength           0.877728    0.683360   0.606454  0.129533
# carwidth            0.867032    0.735433   0.559150  0.182942
# carheight           0.295572    0.067149   0.171071  0.055307
# curbweight               NaN    0.850594   0.648480  0.168790
# enginesize               NaN         NaN   0.583774  0.203129
# boreratio                NaN         NaN        NaN  0.055909
# stroke                   NaN         NaN        NaN       NaN
# compressionratio         NaN         NaN        NaN       NaN
# horsepower               NaN         NaN        NaN       NaN
# peakrpm                  NaN         NaN        NaN       NaN
# citympg                  NaN         NaN        NaN       NaN
# highwaympg               NaN         NaN        NaN       NaN
# price                    NaN         NaN        NaN       NaN
#
#                   compressionratio  horsepower   peakrpm   citympg  \
# symboling                 0.178515    0.070873  0.273606  0.035823
# wheelbase                 0.249786    0.353294  0.360469  0.470414
# carlength                 0.158414    0.552623  0.287242  0.670909
# carwidth                  0.181129    0.640732  0.220012  0.642704
# carheight                 0.261214    0.108802  0.320411  0.048640
# curbweight                0.151362    0.750739  0.266243  0.757414
# enginesize                0.028971    0.809769  0.244660  0.653658
# boreratio                 0.005197    0.573677  0.254976  0.584532
# stroke                    0.186110    0.080940  0.067964  0.042145
# compressionratio               NaN    0.204326  0.435741  0.324701
# horsepower                     NaN         NaN  0.131073  0.801456
# peakrpm                        NaN         NaN       NaN  0.113544
# citympg                        NaN         NaN       NaN       NaN
# highwaympg                     NaN         NaN       NaN       NaN
# price                          NaN         NaN       NaN       NaN
#
#                   highwaympg     price
# symboling           0.034606  0.079978
# wheelbase           0.544082  0.577816
# carlength           0.704662  0.682920
# carwidth            0.677218  0.759325
# carheight           0.107358  0.119336
# curbweight          0.797465  0.835305
# enginesize          0.677470  0.874145
# boreratio           0.587012  0.553173
# stroke              0.043931  0.079443
# compressionratio    0.265201  0.067984
# horsepower          0.770544  0.808139
# peakrpm             0.054275  0.085267
# citympg             0.971337  0.685751
# highwaympg               NaN  0.697599
# price                    NaN       NaN
# <ipython-input-167-7fa700d4b8ca>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr().abs()

# %%
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.8)]
print(); print(to_drop)
# Out:
# ['carlength', 'carwidth', 'curbweight', 'enginesize', 'horsepower', 'citympg', 'highwaympg', 'price']

# %%
df1 = df.copy()
df1.head()
# Out:
#    symboling      CarName fueltype aspiration doornumber      carbody  \
# 0          3  alfa-romero      gas        std        two  convertible
# 1          3  alfa-romero      gas        std        two  convertible
# 2          1  alfa-romero      gas        std        two    hatchback
# 3          2         audi      gas        std       four        sedan
# 4          2         audi      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  ...  enginesize  \
# 0        rwd          front       88.6      168.8  ...         130
# 1        rwd          front       88.6      168.8  ...         130
# 2        rwd          front       94.5      171.2  ...         152
# 3        fwd          front       99.8      176.6  ...         109
# 4        4wd          front       99.4      176.6  ...         136
#
#    fuelsystem  boreratio stroke compressionratio  horsepower peakrpm  citympg  \
# 0        mpfi       3.47   2.68              9.0         111    5000       21
# 1        mpfi       3.47   2.68              9.0         111    5000       21
# 2        mpfi       2.68   3.47              9.0         154    5000       19
# 3        mpfi       3.19   3.40             10.0         102    5500       24
# 4        mpfi       3.19   3.40              8.0         115    5500       18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 25 columns]

# %%
df.drop(['carlength', 'curbweight','enginesize', 'highwaympg','carwidth','horsepower','citympg'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    symboling      CarName fueltype aspiration doornumber      carbody  \
# 0          3  alfa-romero      gas        std        two  convertible
# 1          3  alfa-romero      gas        std        two  convertible
# 2          1  alfa-romero      gas        std        two    hatchback
# 3          2         audi      gas        std       four        sedan
# 4          2         audi      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carheight enginetype cylindernumber  \
# 0        rwd          front       88.6       48.8       dohc           four
# 1        rwd          front       88.6       48.8       dohc           four
# 2        rwd          front       94.5       52.4       ohcv            six
# 3        fwd          front       99.8       54.3        ohc           four
# 4        4wd          front       99.4       54.3        ohc           five
#
#   fuelsystem  boreratio  stroke  compressionratio  peakrpm    price
# 0       mpfi       3.47    2.68               9.0     5000  13495.0
# 1       mpfi       3.47    2.68               9.0     5000  16500.0
# 2       mpfi       2.68    3.47               9.0     5000  16500.0
# 3       mpfi       3.19    3.40              10.0     5500  13950.0
# 4       mpfi       3.19    3.40               8.0     5500  17450.0

# %%
from sklearn.preprocessing import OrdinalEncoder
df2 = df.copy()
ordinal_encoder = OrdinalEncoder()
df2[df_categorical_cols] = ordinal_encoder.fit_transform(df2[df_categorical_cols])

# %%
plt.figure(figsize = (20, 10))
correlation_matrix = df2.corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Cars")

plt.xlabel("Car Features")

plt.ylabel("Car Features")

plt.show()

# %%
strong_feat=correlation_matrix[abs(correlation_matrix['price'])>0.7]
print(strong_feat.price.sort_values())
# Out:
# price    1.0
# Name: price, dtype: float64

# %%
df2.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carheight',
#        'enginetype', 'cylindernumber', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'peakrpm', 'price'],
#       dtype='object')

# %%
y = df2.pop('price')
X = df2

# %%
from sklearn.linear_model import LinearRegression ,ARDRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
LR = LinearRegression()
DTR = DecisionTreeRegressor()
RFR = RandomForestRegressor()
KNR = KNeighborsRegressor()
MLP = MLPRegressor()
XGB = XGBRegressor()

# %%
from sklearn.model_selection import train_test_split
train_X, val_X, train_y, val_y = train_test_split(X, y,test_size=0.30,random_state = 33)
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
def evaluate(model, test_features, test_labels):
    predictions = model.predict(test_features)
    errors = abs(predictions - test_labels)
    mape = 100 * np.mean(errors / test_labels)
    accuracy = 100 - mape
    print('Model Performance')
    print('Average Error: {:0.4f} degrees.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))

    return accuracy

base_model = RandomForestRegressor(random_state=1)
base_model.fit(train_X, train_y)
base_accuracy = evaluate(base_model, val_X, val_y)
# Out:
# Model Performance
# Average Error: 1633.1488 degrees.
# Accuracy = 87.08%.

# %%
from sklearn.metrics import r2_score
li = [LR,DTR,RFR,KNR,KNR,XGB]
d = {}
for i in li:
    i.fit(train_X,train_y)
    ypred = i.predict(val_X)
    print(i,":",r2_score(val_y,ypred)*100)
    d.update({str(i):i.score(val_X,val_y)*100})
# Out:
# LinearRegression() : 69.50363392122547
# DecisionTreeRegressor() : 73.86004421609023
# RandomForestRegressor() : 92.8721317760662
# KNeighborsRegressor() : 32.534426271154615
# KNeighborsRegressor() : 32.534426271154615
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...) : 90.72973823374582

# %%
# Out:
# Model Performance
# Average Error: 1633.1488 degrees.
# Accuracy = 87.08%.
